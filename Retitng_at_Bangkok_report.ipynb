# %% [markdown]
# <a href="https://colab.research.google.com/github/csfoxbom/Coursera_Capstone/blob/master/Retitng_at_Bangkok_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retiring at Bangkok
# Panupong Kongnarg<br>
# 28 March 2021

# %% [markdown]
# ## 1. Introduction <br><br>
#
# ### 1.1 Background
# In fact, Thailand remains one of the top-10 countries to retire abroad, receiving high scores over the past few years in International Living‘s Annual Global Retirement Index—most notably for its top-notch healthcare, inexpensive housing, and friendly residents. These all combine to make it a great choice for retiring overseas. Bangkok, Thailand capital city, is a large Asian city with a cosmopolitan culture and everything you’d expect, and more, than any other major city in the world. Getting around is increasingly easy if you’re willing to go public and take short hops on motorbike taxis.<br>
# ### 1.2 Problem
# Bangkok is a city of diversity in each area. The data we have will be what tells Which area is best for specific personality.<br><br>
# <br><br>
# ## 2. Data acquisition and cleaning <br><br>
#
# ### 2.1 Data sources
# Bangkok geolocation from https://en.wikipedia.org/wiki/List_of_districts_of_Bangkok  and venue data from foursquare API.
#
# ### 2.2 Feature selection
# After receiving the data next, sort the location data by the nearest venue, bringing the top 10 places The most common and use the population (million) to calculate in this project.<br><br><br><br>

# %% [markdown]
# ### 3. Explore the area <br><br>
#
# ![bkkmap.png](data:image/png;base64,...)

# %% [markdown]
# ## Map shown with venue data
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Clustering approach.
# ### 4.1 Find the best K.
# Iterate data througn function that return set of inertia from the K-means algorithm and use blbow method plot. The plot show best K is 5.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.2 Fitting data.
# Use K-means algorithm with 5 clusters. Take cluster labels join with Bangkok data and plot.
#
#
# *   Red = Cluster 0
# *   Purple = Cluster 1
# *   Lightblue = Cluster 2
# *   Lightgreen = Cluster 3
# *   Orange = Cluster 4
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
final_data = pd.read_csv('final.csv')
final_data.shape
# Out:
# (50, 16)

# %% [markdown]
# ## 5. Interprate data from clustering.

# %%
# First Group
final_data[final_data['Cluster Labels'] == 0]
# Out:
#     Unnamed: 0  Cluster Labels Neighborhood  ... Popu-lation   Latitude   Longitude
# 9            9               0     Bang Sue  ...      132234  13.809722  100.537222
# 10          10               0  Bangkok Noi  ...      117793  13.770867  100.467933
# 11          11               0  Bangkok Yai  ...       72321  13.722778  100.476389
# 17          17               0        Dusit  ...      107655  13.776944  100.520556
# 41          41               0       Sathon  ...       84916  13.708056  100.526389
# 42          42               0   Suan Luang  ...      115658  13.730278  100.651389
# 45          45               0    Thon Buri  ...      119708  13.725000  100.485833
#
# [7 rows x 16 columns]

# %%
# First Group
final_data[final_data['Cluster Labels'] == 1]
# Out:
#     Unnamed: 0  Cluster Labels  ...   Latitude   Longitude
# 1            1               1  ...  13.765833  100.647778
# 3            3               1  ...  13.873889  100.596389
# 5            5               1  ...  13.660833  100.435833
# 7            7               1  ...  13.793889  100.505000
# 12          12               1  ...  13.785278  100.669167
# 13          13               1  ...  13.828611  100.559722
# 19          19               1  ...  13.827100  100.674300
# 20          20               1  ...  13.859722  100.704167
# 23          23               1  ...  13.887500  100.578889
# 25          25               1  ...  13.803611  100.607500
# 27          27               1  ...  13.855556  100.862500
# 30          30               1  ...  13.714722  100.437222
# 32          32               1  ...  13.702222  100.601667
# 47          47               1  ...  13.786400  100.608700
# 49          49               1  ...  13.696944  100.543056
#
# ...

# %%
# First Group
final_data[final_data['Cluster Labels'] == 2]
# Out:
#     Unnamed: 0  Cluster Labels  ...   Latitude   Longitude
# 0            0               2  ...  13.659200  100.399100
# 2            2               2  ...  13.696111  100.409444
# 14          14               2  ...  13.677222  100.484722
# 15          15               2  ...  13.769722  100.552778
# 16          16               2  ...  13.913611  100.589722
# 22          22               2  ...  13.708056  100.583889
# 28          28               2  ...  13.704722  100.348889
# 35          35               2  ...  13.716944  100.694444
# 38          38               2  ...  13.919167  100.645833
# 43          43               2  ...  13.776944  100.456667
# 44          44               2  ...  13.787800  100.363800
# 46          46               2  ...  13.647200  100.495800
#
# [12 rows x 16 columns]

# %%
# First Group
final_data[final_data['Cluster Labels'] == 3]
# Out:
#     Unnamed: 0  Cluster Labels Neighborhood  ... Popu-lation   Latitude   Longitude
# 26          26               3     Min Buri  ...      137251  13.813889  100.748056
#
# [1 rows x 16 columns]

# %%
# First Group
final_data[final_data['Cluster Labels'] == 4]
# Out:
#     Unnamed: 0  Cluster Labels  ...   Latitude   Longitude
# 4            4               4  ...  13.693333  100.502500
# 6            6               4  ...  13.680081  100.591800
# 8            8               4  ...  13.730833  100.524167
# 18          18               4  ...  13.776667  100.579444
# 21          21               4  ...  13.730278  100.509722
# 24          24               4  ...  13.722317  100.759669
# 29          29               4  ...  13.744942  100.522200
# 31          31               4  ...  13.780000  100.542778
# 33          33               4  ...  13.764444  100.499167
# 34          34               4  ...  13.758056  100.513056
# 36          36               4  ...  13.682222  100.505556
# 37          37               4  ...  13.758889  100.534444
# 39          39               4  ...  13.731389  100.514167
# 40          40               4  ...  13.770000  100.684722
# 48          48               4  ...  13.742222  100.585833
#
# ...

# %% [markdown]
# ## 6. Conclusion.
# In the beginning, I was expecting to identify areas with hospitals, parks or other facilities needed by the elderly. But what we find is that most of them are restaurants and noodles !! This may be because the proportions of restaurants to other locations are too high.Besides Bangkok There are also large and interesting provinces such as Phuket, Chiang Mai, Chonburi that offer both convenience and Thai identity.
